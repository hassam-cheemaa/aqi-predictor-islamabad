# %% [markdown]
# # Exploratory Data Analysis (EDA) - Islamabad AQI
# This notebook explores the historical air quality data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming data is fetched from Hopsworks or OpenWeather
print('Run feature_pipeline.py to fetch data first.')
